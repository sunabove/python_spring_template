# %%
! rpicam-still -n --immediate -o test.jpg
# Out:
# [0:05:56.373863162] [1957]  INFO Camera camera_manager.cpp:316 libcamera v0.3.1+50-69a894c4
# [0:05:56.556930005] [1963]  WARN RPiSdn sdn.cpp:40 Using legacy SDN tuning - please consider moving SDN inside rpi.denoise
# [0:05:56.566637588] [1963]  INFO RPI vc4.cpp:447 Registered camera /base/soc/i2c0mux/i2c@1/ov5647@36 to Unicam device /dev/media2 and ISP device /dev/media0
# [0:05:56.566929554] [1963]  INFO RPI pipeline_base.cpp:1125 Using configuration file '/usr/share/libcamera/pipeline/rpi/vc4/rpi_apps.yaml'
# Mode selection for 2592:1944:12:P
#     SGBRG10_CSI2P,640x480/0 - Score: 7832
#     SGBRG10_CSI2P,1296x972/0 - Score: 5536
#     SGBRG10_CSI2P,1920x1080/0 - Score: 4238.67
#     SGBRG10_CSI2P,2592x1944/0 - Score: 1000
# Stream configuration adjusted
# [0:05:56.570636522] [1957]  INFO Camera camera.cpp:1191 configuring streams: (0) 2592x1944-YUV420 (1) 2592x1944-SGBRG10_CSI2P
# ...

# %%
from IPython.display import Image

# %%
display( Image('test.jpg') )
